# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (from tiktoken) (2026.3.32)
# Requirement already satisfied: requests>=2.26.0 in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (from tiktoken) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/surajpandey/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2026.2.25)
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import tiktoken

tokenizer = tiktoken.encoding_for_model("gpt-3.5")

# %%
tokenizer.encode("Hello From Surya!!")
# Out:
# [9906, 5659, 328, 3431, 64, 3001]

# %%
tokenizer.decode([9906, 5659, 328, 3431, 64, 3001])
# Out:
# 'Hello From Surya!!'

# %%
tokenizer.n_vocab
# Out:
# 100277

# %%
tokenizer
# Out:
# <Encoding 'cl100k_base'>

# %% [markdown]
# # Text Generation

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

torch_device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained(
    "gpt2",
    pad_token_id=tokenizer.eos_token_id
).to(torch_device)

model_inputs = tokenizer(
    "I enjoy walking with my cute dog",
    return_tensors="pt"
).to(torch_device)
# Out:
# Loading weights: 100%|█████████████████████████████████████████████████| 148/148 [00:00<00:00, 15330.36it/s]

# %%
greedy_output = model.generate(
    **model_inputs,
    max_new_tokens=40
)

print("Output:\n" + 100 * "-")
print(
    tokenizer.decode(
        greedy_output[0],
        skip_special_tokens=True
    )
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ----------------------------------------------------------------------------------------------------
# I enjoy walking with my cute dog, but I'm not sure if I'll ever be able to walk with my dog. I'm not sure if I'll ever be able to walk with my dog.
#
# I'm not sure

# %%
# top p sampling

sample_output = model.generate(
    **model_inputs,
    max_new_tokens=40,
    do_sample=True,
    top_p=0.92,
    top_k=0
)

print("Output:\n" + 100 * '-')
print(tokenizer.decode(sample_output[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ----------------------------------------------------------------------------------------------------
# I enjoy walking with my cute dog Andy but for now, we're here to celebrate the summer's sweet secret:  we grow our own food for our kids.  That's right! The farm is now producing delicious vegetarian
