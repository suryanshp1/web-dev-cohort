# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## PEFT Example

# %%
from transformers import AutoModelForCausalLM
from peft import LoraConfig, TaskType, get_peft_model
import torch

torch_device = "cuda" if torch.cuda.is_available() else "cpu"

model_id = "Qwen/Qwen2.5-3B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map=torch_device
)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 torch_device = "cuda" if torch.cuda.is_available() else "cpu"
#       6
#       7 model_id = "Qwen/Qwen2.5-3B-Instruct"
#       8
# ----> 9 model = AutoModelForCausalLM.from_pretrained(
#      10     model_id,
#      11     device_map=torch_device
#      12 )
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:381, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     379     if model_class.config_class == config.sub_configs.get("text_config", None):
#     380         config = config.get_text_config()
# --> 381     return model_class.from_pretrained(
#     382         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     383     )
#     384 raise ValueError(
#     385     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     386     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     387 )
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/transformers/modeling_utils.py:4052, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4047     logger.warning_once(
#    4048         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4049     )
#    4050     use_kernels = True
# -> 4052 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4053     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4054     variant=variant,
#    4055     gguf_file=gguf_file,
#    4056     use_safetensors=use_safetensors,
#    4057     download_kwargs=download_kwargs_with_commit,
#    4058     user_agent=user_agent,
#    4059     is_remote_code=cls.is_remote_code(),
#    4060     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4061     tqdm_class=tqdm_class,
#    4062 )
#    4064 is_quantized = hf_quantizer is not None
#    4066 if gguf_file:
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/transformers/modeling_utils.py:737, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     735 sharded_metadata = None
#     736 if is_sharded:
# --> 737     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#     738         pretrained_model_name_or_path,
#     739         resolved_archive_file,
#     740         cache_dir=cache_dir,
#     741         force_download=force_download,
#     742         proxies=proxies,
#     743         local_files_only=local_files_only,
#     744         token=token,
#     745         user_agent=user_agent,
#     746         revision=revision,
#     747         subfolder=subfolder,
#     748         _commit_hash=commit_hash,
#     749         tqdm_class=tqdm_class,
#     750     )
#     751 else:
#     752     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/transformers/utils/hub.py:879, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, subfolder, _commit_hash, tqdm_class, **deprecated_kwargs)
#     875     return shard_filenames, sharded_metadata
#     877 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#     878 # or download the files
# --> 879 cached_filenames = cached_files(
#     880     pretrained_model_name_or_path,
#     881     shard_filenames,
#     882     cache_dir=cache_dir,
#     883     force_download=force_download,
#     884     proxies=proxies,
#     885     local_files_only=local_files_only,
#     886     token=token,
#     887     user_agent=user_agent,
#     888     revision=revision,
#     889     subfolder=subfolder,
#     890     _commit_hash=_commit_hash,
#     891     tqdm_class=tqdm_class,
#     892 )
#     894 return cached_filenames, sharded_metadata
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     422         hf_hub_download(
#     423             path_or_repo_id,
#     424             filenames[0],
#    (...)    434             tqdm_class=tqdm_class,
#     435         )
#     436     else:
# --> 437         snapshot_download(
#     438             path_or_repo_id,
#     439             allow_patterns=full_filenames,
#     440             repo_type=repo_type,
#     441             revision=revision,
#     442             cache_dir=cache_dir,
#     443             user_agent=user_agent,
#     444             force_download=force_download,
#     445             proxies=proxies,
#     446             token=token,
#     447             local_files_only=local_files_only,
#     448             tqdm_class=tqdm_class,
#     449         )
#     451 except Exception as e:
#     452     # We cannot recover from them
#     453     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/huggingface_hub/_snapshot_download.py:450, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, dry_run)
#     428 def _inner_hf_hub_download(repo_file: str) -> None:
#     429     results.append(
#     430         hf_hub_download(  # type: ignore
#     431             repo_id,
#    (...)    447         )
#     448     )
# --> 450 thread_map(
#     451     _inner_hf_hub_download,
#     452     filtered_repo_files,
#     453     desc=tqdm_desc,
#     454     max_workers=max_workers,
#     455     tqdm_class=tqdm_class,
#     456 )
#     458 bytes_progress.set_description("Download complete")
#     460 if dry_run:
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File ~/Documents/Python/web-dev-cohort/genai/venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /opt/anaconda3/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## inspect qwen2.5-3B

# %%
model

# %% [markdown]
# ## Apply PEFT

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    task_type=TaskType.CAUSAL_LM,
)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# %%
# train model on your dataset
# save finetuned model
model.save_pretrained("qwen2.5-3b-lora")

# %%
model = PeftModel.from_pretrained(model, "qwen2.5-3b-lora")

inputs = tokenizer(
    "Preheat the oven to 350 degrees and place the cookie dough",
    return_tensors="pt"
)

outputs = model.generate(
    **inputs.to(device),
    max_new_tokens=50
)

print(
    tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )
)
